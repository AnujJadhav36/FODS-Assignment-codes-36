# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airdataset=pd.read_csv("C:/122B1F036/dataset/air.csv" , encoding='windows-1252')
# Out:
# C:\Users\ML\AppData\Local\Temp\ipykernel_4540\3624047474.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   airdataset=pd.read_csv("C:/122B1F036/dataset/air.csv" , encoding='windows-1252')

# %%
airdataset
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
airdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
airdataset.isna().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
airdataset.shape
# Out:
# (435742, 13)

# %%
airdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
airdataset.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(airdataset.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %%
median_values = airdataset["pm2_5"].median()

# %%
median_values
# Out:
# 32.0

# %%
airdataset["so2"]=airdataset["so2"].fillna(airdataset["so2"].median())
airdataset["no2"]=airdataset["no2"].fillna(airdataset["no2"].median())
airdataset["rspm"]=airdataset["rspm"].fillna(airdataset["rspm"].median())
airdataset["spm"]=airdataset["spm"].fillna(airdataset["spm"].median())
airdataset["pm2_5"]=airdataset["pm2_5"].fillna(airdataset["pm2_5"].median())

# %%
airdataset
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(airdataset.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %%
airdataset.dropna(subset=["stn_code"], inplace=True)
airdataset.dropna(subset=["type"], inplace=True)
airdataset.dropna(subset=["location_monitoring_station"], inplace=True)
airdataset.dropna(subset=["date"], inplace=True)

# %%
airdataset
# Out:
#        stn_code sampling_date           state   location             type  \
# 1036       95.0      1/2/2004  Andhra Pradesh  Hyderabad  Industrial Area
# 1037       95.0      1/5/2004  Andhra Pradesh  Hyderabad  Industrial Area
# 1038       95.0      1/9/2004  Andhra Pradesh  Hyderabad  Industrial Area
# 1039       95.0     1/12/2004  Andhra Pradesh  Hyderabad  Industrial Area
# 1040       95.0      16-01-04  Andhra Pradesh  Hyderabad  Industrial Area
# ...         ...           ...             ...        ...              ...
# 435734     SAMP      15-12-15     West Bengal   ULUBERIA            RIRUO
# 435735     SAMP      18-12-15     West Bengal   ULUBERIA            RIRUO
# 435736     SAMP      21-12-15     West Bengal   ULUBERIA            RIRUO
# 435737     SAMP      24-12-15     West Bengal   ULUBERIA            RIRUO
# 435738     SAMP      29-12-15     West Bengal   ULUBERIA            RIRUO
#
#          so2    no2   rspm    spm  \
# 1036    12.9   55.8  143.7  370.7
# ...

# %%
airdataset.isna().sum()
# Out:
# stn_code                       0
# sampling_date                  0
# state                          0
# location                       0
# type                           0
# so2                            0
# no2                            0
# rspm                           0
# spm                            0
# location_monitoring_station    0
# pm2_5                          0
# date                           0
# dtype: int64

# %%
temp = airdataset.groupby(['state'])[['so2', 'no2', 'rspm','spm','pm2_5']].mean().reset_index()

# %%
temp
# Out:
#                    state        so2        no2        rspm         spm  \
# 0         Andhra Pradesh   6.981316  19.046169   75.718160  187.129127
# 1      Arunachal Pradesh   4.411111   9.877778   76.777778  187.000000
# 2                  Assam   6.723959  14.549136   94.190772  187.000000
# 3                  Bihar   7.857585  31.603715  136.795666  177.452012
# 4             Chandigarh   2.897404  21.353339   97.392057  190.347903
# 5           Chhattisgarh  10.643717  23.211670  119.336672  186.745924
# 6   Dadra & Nagar Haveli   8.614563  20.077670   72.906149  141.601942
# 7            Daman & Diu   8.367890  19.881040   70.996942  136.880734
# 8                  Delhi   5.865074  60.990695  208.193037  206.231390
# 9                    Goa   6.278829  12.611290   63.823810  124.644893
# 10               Gujarat  15.110540  23.145721   96.100955  164.458225
# 11               Haryana  13.031157  27.484892  155.198866  201.282789
# ...

# %%
plt.figure(figsize=(20,6))
sns.lineplot(data=temp)
plt.show()
